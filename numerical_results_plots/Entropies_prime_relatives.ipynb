# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Entropy of the Prime state and its Quantum Fourier Transform

# %%
primeentropy = [1.2061876310,1.4748293607,2.3140371226,3.1900293628,4.0220453267,4.8993491051, 5.7871530585,
                6.6748190751,7.5573773542,8.4427538948,9.3301156119,10.215949272,11.101760526,11.987551559,
                12.873188337] # from n=4 up n=32 qubits


primeentropy_odd = [2.5184856999591734,3.3753273289254646,4.226814642661687,5.111994270084174,5.996589086659078,
                    6.883808595696894,7.766481260464697,8.651566936257481,9.536729369287155,10.421832880815533,
                    11.307017652399958] # from n=9 up to n=29 qubits

QFT_primeentropy = [2.362906770936273,3.2086792977605527,4.034132994859772,4.910162535785778,5.803042071446673,
                    6.682105429938958,7.564120735955006,8.447073177104569] # from n=8 up to n=22 qubits

# %%
plt.plot(range(8,30,2),primeentropy[2:13],'o-',range(9,31,2),primeentropy_odd,'o-')
plt.plot(range(8,24,2),QFT_primeentropy,'o-')

plt.rcParams["axes.linewidth"]=1.3
plt.xticks(range(9,31,2),range(9,31,2))
plt.legend(('Prime (n even)','Prime (n odd)','QFT Prime (n even)'),loc=4)
plt.xlabel('n')
plt.ylabel('S')
plt.grid()
plt.title('Entropy of the Prime State and its QFT')
# Out:
# Text(0.5, 1.0, 'Entropy of the Prime State and its QFT')

# %% [markdown]
# # Entropy of the Prime state in qudit bases

# %%
primeentropy3 = [1.3222423576317404,1.9783643665005672,2.8182664098026597,3.6972515092301035,
              4.586092864681913,5.475368945071017,6.363177140879514,7.2502793023430625] # from n=4 up to n=18 qubits

primeentropy4 = [1.1570185613042894,2.0110226633251793,2.8935765292334135,
              3.7786886770919623,4.6650578059346515,5.550880262857744] # from n=4 up to n=14 qubits

primeentropy5 = [1.4093705028301902,2.24857757472841,3.1248101141882594,
              4.009716720509546,4.8959837134809145] # from n=4 up to n=12 qubits

# %%
plt.plot(range(6,20,2),primeentropy[1:8],'o-', range(6,20,2),primeentropy3[1:],'o-', 
         range(6,16,2),primeentropy4[1:],'o-',range(6,14,2),primeentropy5[1:],'o-')

plt.rcParams["axes.linewidth"]=1.3
plt.legend(('q=2','q=3','q=4','q=5'),loc=4)
plt.xticks(range(6,22,2),range(6,22,2))
plt.xlabel('n')
plt.ylabel('S')
plt.grid()
plt.title('Entropy of Prime States in q-nary basis')
# Out:
# Text(0.5, 1.0, 'Entropy of Prime States in q-nary basis')

# %% [markdown]
# # Entropy of Arithmetic Prime states

# %%
primeentropy_1mod4 = [0.8112781244591328,1.713720170722651,2.5940262755266206,3.477496564537296,4.328439990784457,
                    5.191943152334872,6.077963714435838,6.957559264561142,7.8394581414809865,8.72396189867712,
                    9.607392534257073,10.490792263377854,11.374819205252216] # from n=6 up to n=30 qubits

primeentropy_3mod4 = [0.6392357669076902,1.6540650456411432,2.4907504048861284,3.3916292019398466,4.297290737424576,
                    5.188998609034037,6.071574080618127,6.9539914941131,7.8371164405787541, 8.722589029308645,
                    9.606418672557835,10.490784188693983,11.374824417017951] # from n=6 up to n=30 qubits



primeentropy_1mod8 = [1.0000,1.9031811999323667,2.7690063201653095,3.656054126641285,4.506492889412223,
                        # from n=12 up to n=30 qubits

primeentropy_3mod32 = [0.9613785302093862,1.908975356996386,2.831338762973661,3.7812843136640772,4.686398786108268,
                       5.588566616608494,6.479737250201802,7.3742804057929385,8.263927801967613,9.15244639433098]
                        # from n=12 up to n=30 qubits

primeentropy_5mod32 = [0.9402164313222008,1.883119722249756,2.8505945019687937,3.7691074659040686,4.681092879172144,
                       5.5858529237659695,6.48181674918051,7.375058515474971,8.264493547214323,9.15268925296747]
                        # from n=12 up to n=30 qubits

primeentropy_7mod32 = [0.9596587088976745,1.9028492646317945,2.857441665885406,3.774808956105648,4.6883274012096,
                       5.585017907045114,6.484234154870618,7.374856148130346,8.26464271913956,9.15292332105828]
                        #desde n=12 hasta n=30 qubits

primeentropy_9mod32 = [0.9798687566511527,1.9427693922211897,2.8487794069868975,3.7729612408213815,4.676547744777377,
                       5.589461004796508,6.485447097224951,7.376171807444682,8.265250563508813,9.153036955485087]
                        #desde n=12 hasta n=30

primeentropy_11mod32 = [0.9494520153879485,1.8972022053389332,2.8536875280643663,3.779936378055668,4.6842586285170595,
                        5.588492817417903,6.484611457710759,7.3757908398196586,8.264443079933296,9.152727634343536]
                        # from n=12 up to n=30 qubits

primeentropy_13mod32 = [0.9970537182205588,1.945560993503881,2.8567775154817765,3.7762512287101715,4.6884659263215145,
                        5.58401179448998,6.482938236888789,7.375091044753629,8.264291071078963,9.152575424880384]
                        # from n=12 up n=30 qubits

primeentropy_15mod32 = [0.9846650349843397,1.913364111789636,2.8265886832900953,3.7548964183952234,4.682189898569716,
                        5.5882464632258975,6.482052404410767,7.375603975607921,8.265161495421106,9.152764458179847]
                        # from n=12 up to n=30 qubits

primeentropy_17mod32 = [0.9565054811874001,1.926551501542665,2.8544055922886904,3.774900158071609,4.686441987083014,
                        5.587763678333415,6.48516544939679,7.375044954070596,8.26480743589667,9.152796703202082]
                        # from n=12 up to n=30 qubits

primeentropy_19mod32 = [0.9550025719107216,1.899917812039131,2.8603599187172177,3.7815446731878617,4.685453317127139,
                        5.584630606766713,6.483214791106082,7.376731289986856,8.265198988915222,9.152939645436918]
                        # from n=12 up to n=30 qubits

primeentropy_21mod32 = [0.9761571565384972,1.9244235920123474,2.851499288453366,3.780604670787371,4.686364828179596,
                        5.585432674109726,6.482873832900337,7.375273378795561,8.264426379250352,9.15286600798862]
                        # from n=12 up to n=30 qubits

primeentropy_23mod32 = [0.9887098125929181,1.8982356193563965,2.851835793875505,3.7732863531008456,4.683476571704048,
                        5.582850288308974,6.483153639623482,7.37476423642149,8.264744110499668,9.152848955069672]
                        # from n=12 up to n=30 qubits

primeentropy_25mod32 = [0.9811522341999134,1.9313553720631538,2.855879268001501,3.7805393111000702,4.685556044423132,
                        5.584488445202994,6.482975986971865,7.374791086594451,8.264540485065021,9.152663638293856]
                        # from n=12 up to n=30 qubits

primeentropy_27mod32 = [0.9910238023903253,1.9126492869600493,2.854826873255546,3.780545109152162,4.68750252018434,
                        5.581639649252704,6.483087077183637,7.374758732841808,8.264648624234194,9.15279931461784]
                        # from n=12 up to n=30 qubits

primeentropy_29mod32 = [0.9677884628267678,1.9167063543854879,2.8533176936199998,3.7750142706986654,4.684865198757418,
                        5.581007137711771,6.483102858545439,7.375031922712027,8.264654210182067,9.152791851640012]
                        # from n=12 up to n=30 qubits

primeentropy_31mod32 = [0.9699834934108893,1.9016526866012693,2.847549805894503,3.784636726575648,4.6837984251641736,
                        5.587267584301971,6.482340740635189,7.3741713644941,8.26426151659516,9.152713639553781]
                        # from n=12 up to n=30 qubits

# %%
plt.plot(range(8,32,2),primeentropy[2:-1],'o-', range(8,32,2),primeentropy_1mod4[1:],'o-', 
         range(8,32,2),primeentropy_3mod4[1:],'o-', range(8,32,2),primeentropy_1mod8,'o-', 
         range(8,32,2),primeentropy_3mod8,'o-', range(8,32,2),primeentropy_5mod8,'o-', 
         range(8,32,2),primeentropy_7mod8,'o-')

plt.rcParams["axes.linewidth"]=1.3
plt.xticks(range(8,32,2),range(8,32,2))
plt.legend(('Primes','Primes 1 mod 4','Primes 3 mod 4','Primes 1 mod 8','Primes 3 mod 8','Primes 5 mod 8','Primes 7 mod 8'),loc=4)
plt.xlabel('n',fontsize=12)
plt.ylabel('S',fontsize=12)
plt.grid()
plt.title('Entropy of Arithmetic Prime States')
# Out:
# Text(0.5, 1.0, 'Entropy of Arithmetic Prime States')

# %% [markdown]
# # Entropy of Prime state relatives

# %%
odd_composite = [1.0,1.175176840833449,1.852733969040693,2.017240229340669,2.0317131447764076,2.0121253737507705,
                 1.9779984562358655,1.9442067040976125,1.9091411267976137,1.8765415280287276,1.8464967833017873,
                 1.8190396012341445,1.793996891734006] # from n=4 up to n=28 qubits

odd_squarefree = [0.928063149518636,1.0183800408833168,1.158357772835734,1.3379586553790268,1.4893753692284224,
                  1.6210052514016096,1.7221442123024795,1.8028095966792885,1.8631179661764221,1.9117199243928924,
                  1.9504931486318113,1.9818442591631722,2.0068653723154837] # from n=4 up to n=28 qubits

Mobius = [3.9999328472748026,5.052030062413108,6.042807760437664,7.04974552212264,8.042144985411628,
          9.04349944266207,10.04281573274986,11.044164762259852,12.044076103775812,13.043919323947994]
            # from n=14 up to n=28 qubits

# %%
plt.plot(range(10,30,2),primeentropy[3:-2],'o-')
plt.plot(range(10,30,2),odd_composite[3:],'o-')
plt.plot(range(10,30,2),odd_squarefree[3:],'o-')
plt.plot(range(10,30,2),Mobius,'o-',color='violet')

plt.rcParams["axes.linewidth"]=1.3
plt.xticks(range(10,30,2),range(10,30,2))
plt.legend(('Primes','Odd Composites','Odd Square-Free','Möbius'),loc=2)
plt.xlabel('n',fontsize=12)
plt.ylabel('S',fontsize=12)
plt.grid()
plt.title('Entropy of Odd Composite, Odd Square-Free\n'+' and Möbius States')
# Out:
# Text(0.5, 1.0, 'Entropy of Odd Composite, Odd Square-Free\n and Möbius States')

# %%
starry1 = [1.2213861083962008,2.0848672522834946,3.0498177755324427,3.995159802311694,4.958170772015349,
           5.961929817576347,6.946791918281435,7.9303843434334444,8.918634359462663,9.898500428617423,
           10.882048337990799,11.864951991297644,12.849633160614351,13.835126993920017] # from n=4 up to n=30 qubits

starry2 = [1.3033447133650973,1.7939646168408256,2.9792441221341375,3.916347514574262,4.926880661967635,
           5.951435660659718,6.94459594863875,7.934341473820407,8.916414837020302,9.899322107325851,
           10.881609549076003,11.865245252283485,12.849566448719475,13.83508714507669] # from n=4 up to n=30 qubits

starry3 = [0.9279366924466294,1.8441092219198576,2.883508150234086,3.951822653138302,4.933527174468666,
           5.945526346933948,6.943841540790877,7.9346332148873655,8.916084502851264,9.898516581864431,
           10.881577451713826,11.865208869710434,12.849508740042511,13.835081779357381] # from n=4 up to n=30 qubits

starry4 = [1.3033447133650973,2.2061207147050133,2.846791981231505,3.8871387786238296,4.948444680503816,
           5.943023162620228,6.945907322064519,7.930243564886971,8.916140127424553,9.898795878628844,
           10.881318722216344,11.864947084895391,12.849474342871758,13.83510175969165] # from n=4 up to n=30 qubits

starry5 = [1.3616541669070519,2.066764657092659,2.9123748677294845,3.9109099784393386,4.9875485118839045,
           5.952948984313665,6.949539274337908,7.9294229941876955,8.917062050632095,9.897535685502417,
           10.881668638278963,11.865027054770186,12.849482589969243,13.835178019720937] # from n=4 up to n=30 qubits

starry6 = [1.2213861083962008,2.05499475813848,2.820103156118311,3.9265902565984288,4.95688461044769,
           5.938853221702881,6.941107869606144,7.934269952840574,8.917861040671273,9.898738895305359,
           10.881601184044614,11.864855168396552,12.849450938649188,13.835112784687718] # from n=4 up to n=30 qubits

starry7 = [1.3616541669070519,2.208808949202689,2.923154416399761,3.934795473562289,4.924939935589368,
           5.9608055125252335,6.949727304429462,7.932151141731011,8.91668009728059,9.899433444301346,
           10.881534919259591,11.864930946998976,12.849503362486466,13.83511849909893] # from n=4 up to n=30 qubits

starry8 = [0.9279366924466294,1.8086998684218132,2.8939851818160967,3.8980919032244397,4.988987551997776,
           5.970843764151015,6.944208199070014,7.933161180211616,8.918797751079772,9.89828262524458,
           10.881485923256829,11.8650626969253,12.849545837370519,13.835087608043677] # from n=4 up to n=30 qubits

starry9 = [0.9279366924466294,2.0312884003958462,2.9906566718411387,3.857623289587391,4.948479934165761,
           5.959400245330651,6.9438370035944965,7.931427145679486,8.916801134301721,9.898913764641991,
           10.881743545085278,11.865108333234017,12.849460823900664,13.835076766488388] # from n=4 up to n=30 qubits

starry10 = [0.9279366924466294,1.6707329848756585,2.8755464913234765,3.9456116156063823,4.923637629906356,
            5.949732829065159,6.947295320123307,7.933624402126084,8.9167602786306,9.897314333802267,
            10.882195092292006,11.865088021235568,12.84960196474086,13.835057652498529] # from n=4 up to n=30 qubits


starryprimes = [np.mean([starry1[i],starry2[i],starry3[i],starry4[i],starry5[i],starry6[i],starry7[i],starry8[i],
                     starry9[i],starry10[i]]) for i in range(14)]

# %%
plt.plot(range(8,32,2),primeentropy[2:-1],'o-')
plt.plot(range(8,32,2),starryprimes[2:],'ro-')

plt.rcParams["axes.linewidth"]=1.3
plt.xticks(range(8,32,2),range(8,32,2))
plt.legend(('Primes','Starry primes'),loc=4)
plt.xlabel('n',fontsize=12)
plt.ylabel('S',fontsize=12)
plt.grid()
plt.title('Entropy of Random Starry-Prime States')
# Out:
# Text(0.5, 1.0, 'Entropy of Random Starry-Prime States')
