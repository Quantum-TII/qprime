            # from m=1 up to m=25 qubits

entropys28 = [1.725478467092386e-06,0.9962337821321596,1.9837486551710188,2.9572401023227957,
            3.912188579507773,4.8387638246014655,5.738091461158819,6.61065914240156,
            7.457789902231395,8.280377414016158,9.078590541772348,9.846423392984,
            10.557193102591643,11.101760525715491,11.10149722817397,10.556543377102203,
            9.84551028677831,9.077465376505232,8.27907732471615,7.456335611985358,6.608993233751391,
            5.736288422623961,4.836677849138023,3.9099126022100585,2.9551311712300135,1.9818669776360427,
            0.9951653136769654] # from m=1 up to m=27 qubits

# %%
plt.plot(range(1,16),entropys16,'o-',color='fuchsia')
plt.plot(range(1,18),entropys18,'o-',color='darkviolet')
plt.plot(range(1,20),entropys20,'o-',color='mediumblue')
plt.plot(range(1,22),entropys22,'o-',color='limegreen')
plt.plot(range(1,24),entropys24,'o-',color='yellow')
plt.plot(range(1,26),entropys26,'o-',color='orange')
plt.plot(range(1,28),entropys28,'o-',color='orangered')

plt.rcParams["axes.linewidth"]=1.3
plt.xticks(range(1,32,2),range(1,31,2))
plt.legend(('16 qubits','18 qubits','20 qubits','22 qubits','24 qubits','26 qubits','28 qubits'))
plt.xlabel('m',fontsize=12)
plt.ylabel('S',fontsize=12)
plt.grid()
plt.title('Entropy of the Prime State for bipartitions of size m')
# Out:
# Text(0.5, 1.0, 'Entropy of the Prime State for bipartitions of size m')

# %%
plt.plot(np.array(range(1,16))/16, np.array(entropys16)/entropys16[7],'o-',color='fuchsia')
plt.plot(np.array(range(1,18))/18, np.array(entropys18)/entropys18[8],'o-',color='darkviolet')
plt.plot(np.array(range(1,20))/20, np.array(entropys20)/entropys20[9],'o-',color='mediumblue')
plt.plot(np.array(range(1,22))/22, np.array(entropys22)/entropys22[10],'o-',color='limegreen')
plt.plot(np.array(range(1,24))/24, np.array(entropys24)/entropys24[11],'o-',color='yellow')
plt.plot(np.array(range(1,26))/26, np.array(entropys26)/entropys26[12],'o-',color='orange')
plt.plot(np.array(range(1,28))/28, np.array(entropys28)/entropys28[13],'o-',color='orangered')

plt.rcParams["axes.linewidth"]=1.3
plt.legend(('16 qubit','18 qubit','20 qubits','22 qubits','24 qubits','26 qubits','28 qubits'))
plt.xlabel('m / n',fontsize=12)
plt.ylabel('S / S(n/2)',fontsize=12)
plt.grid()
plt.title('Entropy of the Prime State for bipartitions of size m')
# Out:
# Text(0.5, 1.0, 'Entropy of the Prime State for bipartitions of size m')
